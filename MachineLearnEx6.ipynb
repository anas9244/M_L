# %% [markdown]
# # Exercise 6
# # b)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as mpatches


data = np.genfromtxt("Fisher.txt",delimiter='\t')

Setosa = data[:,][:,0]==0
Verginica = data[:,][:,0]==1
Versicolor = data[:,][:,0]==2


# init for mean,max and min
pwSetosa=data[Setosa][:,1]
pwVerginica=data[Verginica][:,1]
pwVersicolor=data[Versicolor][:,1]

plSetosa=data[Setosa][:,2]
plVerginica=data[Verginica][:,2]
plVersicolor=data[Versicolor][:,2]

swSetosa=data[Setosa][:,3]
swVerginica=data[Verginica][:,3]
swVersicolor=data[Versicolor][:,3]


slSetosa=data[Setosa][:,4]
slVerginica=data[Verginica][:,4]
slVersicolor=data[Versicolor][:,4]



#init for RSS & LMS

# x
Setosa_Verginica = data[ data[:,][:,0]!=2 ][:,0]

# y 
slSetosa_Verginica=data[data[:,][:,0]!=2][:,4]









#The Means
#---------------------------------------------------------------------------------------------------------
print ('## The Means ##\n')
# Petal Widtth Means

print('Mean of Setosa Petal Width')
print (np.mean(pwSetosa))
print('Mean of Verginica Petal Width')
print (np.mean(pwVerginica))
print('Mean of Versicolor Petal Width')
print (np.mean(pwVersicolor))

print ('\n')

#Petal Length Means
print('Mean of Setosa Petal Length')
print (np.mean(plSetosa))
print('Mean of Verginica Petal Length')
print (np.mean(plVerginica))
print('Mean of Versicolor Petal Length')
print (np.mean(plVersicolor))

print ('\n')

#Sepal Widtth Means
print('Mean of Setosa Petal Width')
print (np.mean(swSetosa))
print('Mean of Verginica Petal Width')
print (np.mean(swVerginica))
print('Mean of Versicolor Petal Width')
print (np.mean(swVersicolor))


print ('\n')

#Sepal Length Means
print('Mean of Setosa Petal Length')
print (np.mean(slSetosa))
print('Mean of Verginica Petal Length')
print (np.mean(slVerginica))
print('Mean of Versicolor Petal Length')
print (np.mean(slVersicolor))

print ('\n')


#The minimums
#--------------------------------------------------------------------------------------------------------------------------

print ('\n## The minimums ##')
print ('------------------------------------------------------------------------\n')
# Petal Widtth minimums

print('Minimun of Setosa Petal Width')
print (np.min(pwSetosa))
print('Minimun of Verginica Petal Width')
print (np.min(pwVerginica))
print('Minimun of Versicolor Petal Width')
print (np.min(pwVersicolor))

print ('\n')

#Petal Length minimums
print('Minimun of Setosa Petal Length')
print (np.min(plSetosa))
print('Minimun of Verginica Petal Length')
print (np.min(plVerginica))
print('Minimun of Versicolor Petal Length')
print (np.min(plVersicolor))

print ('\n')

#Sepal Widtth minimums
print('Minimun of Setosa Petal Width')
print (np.min(swSetosa))
print('Minimun of Verginica Petal Width')
print (np.min(swVerginica))
print('Minimun of Versicolor Petal Width')
print (np.min(swVersicolor))


print ('\n')

#Sepal Length minimums
print('Minimun of Setosa Petal Length')
print (np.min(slSetosa))
print('Minimun of Verginica Petal Length')
print (np.min(slVerginica))
print('Minimun of Versicolor Petal Length')
print (np.min(slVersicolor))

print ('\n')



#The max
#--------------------------------------------------------------------------------------------------------------------------

print ('\n## The maximums ##')
print ('------------------------------------------------------------------------\n')
# Petal Widtth maximums

print('Maximum of Setosa Petal Width')
print (np.max(pwSetosa))
print('Maximum of Verginica Petal Width')
print (np.max(pwVerginica))
print('Maximum of Versicolor Petal Width')
print (np.max(pwVersicolor))

print ('\n')

#Petal Length maximums
print('Maximum of Setosa Petal Length')
print (np.max(plSetosa))
print('Maximum of Verginica Petal Length')
print (np.max(plVerginica))
print('Maximum of Versicolor Petal Length')
print (np.max(plVersicolor))

print ('\n')

#Sepal Widtth maximums
print('Maximum of Setosa Petal Width')
print (np.max(swSetosa))
print('Maximum of Verginica Petal Width')
print (np.max(swVerginica))
print('Maximum of Versicolor Petal Width')
print (np.max(swVersicolor))


print ('\n')

#Sepal Length maximums
print('Maximum of Setosa Petal Length')
print (np.max(slSetosa))
print('Maximum of Verginica Petal Length')
print (np.max(slVerginica))
print('Maximum of Versicolor Petal Length')
print (np.max(slVersicolor))

print ('\n')
# Out:
# ## The Means ##
#
# Mean of Setosa Petal Width
# 2.46
# Mean of Verginica Petal Width
# 20.06
# Mean of Versicolor Petal Width
# 13.26
#
#
# Mean of Setosa Petal Length
# 14.62
# Mean of Verginica Petal Length
# 55.52
# Mean of Versicolor Petal Length
# 43.22
#
#
# Mean of Setosa Petal Width
# 34.28
# Mean of Verginica Petal Width
# 29.74
# Mean of Versicolor Petal Width
# 27.64
#
#
# Mean of Setosa Petal Length
# 50.1
# Mean of Verginica Petal Length
# 65.88
# Mean of Versicolor Petal Length
# 59.36
#
#
#
# ## The minimums ##
# ------------------------------------------------------------------------
#
# Minimun of Setosa Petal Width
# 1.0
# Minimun of Verginica Petal Width
# 13.0
# Minimun of Versicolor Petal Width
# 10.0
#
#
# Minimun of Setosa Petal Length
# 10.0
# Minimun of Verginica Petal Length
# 45.0
# Minimun of Versicolor Petal Length
# 30.0
#
#
# Minimun of Setosa Petal Width
# 23.0
# Minimun of Verginica Petal Width
# 22.0
# Minimun of Versicolor Petal Width
# 20.0
#
#
# ...

# %% [markdown]
# ### We can easily distinguish the setosa since its mean values (exept for the petal width) are generally smaller compared to the other species'. While the Verginica and Versicolor mean values are almost close in all of the measurements, exept for the petal width where the two species are easily distinguishable.

# %% [markdown]
# # c)

# %%
plt.title('Sepal and petal length for the 3 species',fontsize=25)
plt.xlabel("Petal Length",fontsize=15)
plt.ylabel("Sepal Length",fontsize=15)

plt.scatter(plSetosa,slSetosa,facecolor='red',label='Setosa');
plt.scatter(plVerginica,slVerginica,facecolor='blue',label='Verginica');
plt.scatter(plVersicolor,slVersicolor,facecolor='green',label='Versicolor');


plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=15)


fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 12
fig_size[1] = 7
plt.rcParams["figure.figsize"] = fig_size
plt.grid()
plt.show()

# %% [markdown]
# # d)

# %%
plt.title('Sepal length for the 3 Setosa + Virginica',fontsize=25)
plt.xlabel("Sepal Length",fontsize=15)



plt.scatter(slSetosa_Verginica,Setosa_Verginica,facecolor='red');


fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 6
plt.rcParams["figure.figsize"] = fig_size
plt.ylim([-1,2])
plt.yticks(np.arange(2),('Setosa (0)','Virginica (1)'))

plt.show()

# %%
x= slSetosa_Verginica
y=Setosa_Verginica

examples = np.vstack([np.ones_like(x), x, y])
examples = examples.T

def rss(examples, w):
    """Compute the residual sum of squares for a linear model.
       
       Arguments:
       examples -- (n, p + 1)-matrix of predictors and response
       w        -- p-vector of linear model weights
    """
    x = examples[:,:-1]    ### First p columns: shape = (n, p)
    y = examples.T[-1]     ### Last column: shape = (n,)
    y_pred = w.dot(x.T)
    rss = (y - y_pred)**2
    ### Note: w.dot(x) has shape = (n,)
    return rss.sum()




def lms(examples, eta, iterations, print_every=1000):
    np.random.seed(2)
    rows, columns = examples.shape
    p = columns - 1 ### last column is the response variable
    w = np.random.uniform(low=-1.0, high=1.0, size=p)
    
    for iteration in range(iterations):
        rand = np.random.randint(0, rows)  ### select random index
        x = examples[rand,:-1]   ### Everything but the last column
        c = examples[rand,-1:]   ### The last column
        
        y = w.dot(x)
        error = c - y            ### Error in the single chosen example
        w += (eta * error * x) 
        
        if iteration % print_every == 0:
            print("Iteration: {} RSS: {:.2f}".format(iteration, 
                                                     rss(examples, w)))
    return w

# %% [markdown]
# ##  RSS

# %%
w = lms(examples, eta=0.0004, iterations=210000, print_every=10000)
# Out:
# Iteration: 0 RSS: 64705.87
# Iteration: 10000 RSS: 79.68
# Iteration: 20000 RSS: 36.15
# Iteration: 30000 RSS: 33.50
# Iteration: 40000 RSS: 15.20
# Iteration: 50000 RSS: 41.55
# Iteration: 60000 RSS: 27.49
# Iteration: 70000 RSS: 38.55
# Iteration: 80000 RSS: 46.75
# Iteration: 90000 RSS: 18.89
# Iteration: 100000 RSS: 9.02
# Iteration: 110000 RSS: 13.08
# Iteration: 120000 RSS: 98.16
# Iteration: 130000 RSS: 45.08
# Iteration: 140000 RSS: 8.23
# Iteration: 150000 RSS: 14.89
# Iteration: 160000 RSS: 10.38
# Iteration: 170000 RSS: 21.41
# Iteration: 180000 RSS: 8.02
# Iteration: 190000 RSS: 47.35
# Iteration: 200000 RSS: 10.55

# %% [markdown]
# ## Weight vector

# %%
w
# Out:
# array([-1.86748261,  0.0389549 ])

# %% [markdown]
# ## Line of best fit

# %%
sl_trans = x.T


line_x = [min(sl_trans), max(sl_trans)]
line_y = [predict_temperature(v) for v in line_x]





plt.scatter(x, y,facecolor='red')

plt.plot(line_x, line_y, 'b');


plt.xlabel("Sepal length")

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 6
plt.rcParams["figure.figsize"] = fig_size

plt.ylim([-1,2])
plt.yticks(np.arange(2),('Setosa (0)','Virginica (1)'))


plt.show()
